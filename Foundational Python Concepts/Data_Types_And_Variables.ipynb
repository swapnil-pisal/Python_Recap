# %% [markdown]
# # Data Types & Variables:
# Mastery of integers, floats, strings, and booleans for data representation.

# %%
print("hello World")
# Out:
# hello World

# %%
# variable 
num=12
print(num)
print(type(num))
# Out:
# 12
# <class 'int'>

# %%
# integer 
a=12
print(a)
print(type(a))
# Out:
# 12
# <class 'int'>

# %%
# float 
b=21.43
print(b)
print(type(b))
# Out:
# 21.43
# <class 'float'>

# %%
c="swapnil"
print(c)
print(type(c))
# Out:
# swapnil
# <class 'str'>

# %%
d=True
print(d)
print(type(d))
# Out:
# True
# <class 'bool'>

# %%
# print different way
num=32
print("The number is : ",num)
print("The type of number is  : ",type(num))

# newline charcter
print("The number is : \n",num)
print("The type of number is  : \n",type(num))

# f string
print(f"The number is : {num}")
print(f"The type of number is  {num}")
# Out:
# The number is :  32
# The type of number is  :  <class 'int'>
# The number is :
#  32
# The type of number is  :
#  <class 'int'>
# The number is : 32
# The type of number is  32

# %%
#adition of two elementa
a=10
b=12
print(f"The addition of two number {a+b}")
# Out:
# The addition of two number 22

# %%
# user input for

# integer number
num1=int(input("Enter the first number :"))

# float number
num2=float(input("Enter the second number :"))

# string as input
num3=input("Enter the sring :")
# Out:
# Enter the first number : 12
# Enter the second number : 22.22
# Enter the sring : swapnil

# %%
# the element in the string access using index
s="Swapnil"
print(s[0:1])
print(s[2:4])
# Out:
# S
# ap
